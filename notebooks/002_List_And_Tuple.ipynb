# %% [markdown]
# # List And Tuple

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = [1,2,3,4,5]

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list([1,2,3,4,5]) # list constructor
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list2 = [1, 2.3, "hello", "A"]

# %%
list2
# Out:
# [1, 2.3, 'hello', 'A']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l1 = [1,2,3]
l2 = [3, 1, 2]

# %%
l1==l2
# Out:
# False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Hello, guys, and welcome to Python Programming Tutorials by Amoleas Academy. We were discussing data structures in Python programming language. In the previous tutorial, we explored the different types of data structures: built-in data structures and user-defined data structures. Today, we'll focus on built-in data structures, specifically the list and tuple. If you want a more detailed explanation, you can find the link to the previous video tutorial in the description box.
Hello guys and welcome to Python Programming Tutorials by Amoleas Academy. We were discussing about data structures in Python programming language and in the previous tutorial we saw the different type of data structures that is the built-in data structure and user defined data structure. So first we will discuss about the built-in data structure. So today in this tutorial we will talk about the list and tuple. We already discussed about list and tuple previously in detail. Here I will explain about this concepts briefly. If you want detailed explanation I will give you the link of the previous video tutorial in the description box.
