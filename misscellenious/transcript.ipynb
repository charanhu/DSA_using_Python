# %%
from langchain.document_loaders import YoutubeLoader

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=8e_PwxYGZrA&list=PLzgPDYo_3xukPJdH6hVQ6Iic7KiJuoA-l", 
    add_video_info=False,
    language=["en", "id"],
    translation="en",
)

# %%
loader.load()
# Out:
# ---------------------------------------------------------------------------
# NoTranscriptFound                         Traceback (most recent call last)
# File ~/VS_Code/GitHub/DSA_using_Python/venv/lib/python3.11/site-packages/langchain_community/document_loaders/youtube.py:208, in YoutubeLoader.load(self)
#     207 try:
# --> 208     transcript = transcript_list.find_transcript(self.language)
#     209 except NoTranscriptFound:
#
# File ~/VS_Code/GitHub/DSA_using_Python/venv/lib/python3.11/site-packages/youtube_transcript_api/_transcripts.py:183, in TranscriptList.find_transcript(self, language_codes)
#     170 """
#     171 Finds a transcript for a given language code. Manually created transcripts are returned first and only if none
#     172 are found, generated transcripts are used. If you only want generated transcripts use
#    (...)
#     181 :raises: NoTranscriptFound
#     182 """
# ...
